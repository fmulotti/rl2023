# %% [markdown]
# <a href="https://colab.research.google.com/github/fmulotti/rl2023/blob/main/02_karm_stat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bras1_moyenne=0.5
bras1_et=0.10

bras2_moyenne=0.45
bras2_et=0.20

# %%
sample = [ 10, 100, 1000, 1000, 10000 ]
for i in sample:
  np.random.seed(2024)
  bras1=np.random.normal(0.5,0.10,i)
  bras2=np.random.normal(0.4,0.3,i)
  plt.figure()
  plt.hist(bras2,color="RED",label="Bras2",bins=51)
  plt.hist(bras1,color="blue",label="bras1",bins=51)
  plt.legend()
  plt.xlim(0,1)
  plt.ylabel("Fréquence")
  plt.title(f"{i} tirages")
  plt.show()

# %%
print(f"Moyenne bras 1 : {np.average(bras1)}, moyenne bras 2 : {np.average(bras2)}")
# Out:
# Moyenne bras 1 : 0.5007695829793319, moyenne bras 2 : 0.40095668249961913

# %% [markdown]
# Pourtant les moyennes parlent d'eux meme.
# Le rendement moyen du bras 1 est largement supérieur
